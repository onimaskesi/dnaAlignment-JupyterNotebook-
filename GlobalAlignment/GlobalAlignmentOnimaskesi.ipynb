# %%
bosluk = '_'

sembol_eslesme = '*'
sembol_eslesmeme = '!'
sembol_bosluk = ' '

blosum62 = {
    ('W', 'F'): 1, ('L', 'R'): -2, ('S', 'P'): -1, ('V', 'T'): 0,
    ('Q', 'Q'): 5, ('N', 'A'): -2, ('Z', 'Y'): -2, ('W', 'R'): -3,
    ('Q', 'A'): -1, ('S', 'D'): 0, ('H', 'H'): 8, ('S', 'H'): -1,
    ('H', 'D'): -1, ('L', 'N'): -3, ('W', 'A'): -3, ('Y', 'M'): -1,
    ('G', 'R'): -2, ('Y', 'I'): -1, ('Y', 'E'): -2, ('B', 'Y'): -3,
    ('Y', 'A'): -2, ('V', 'D'): -3, ('B', 'S'): 0, ('Y', 'Y'): 7,
    ('G', 'N'): 0, ('E', 'C'): -4, ('Y', 'Q'): -1, ('Z', 'Z'): 4,
    ('V', 'A'): 0, ('C', 'C'): 9, ('M', 'R'): -1, ('V', 'E'): -2,
    ('T', 'N'): 0, ('P', 'P'): 7, ('V', 'I'): 3, ('V', 'S'): -2,
    ('Z', 'P'): -1, ('V', 'M'): 1, ('T', 'F'): -2, ('V', 'Q'): -2,
    ('K', 'K'): 5, ('P', 'D'): -1, ('I', 'H'): -3, ('I', 'D'): -3,
    ('T', 'R'): -1, ('P', 'L'): -3, ('K', 'G'): -2, ('M', 'N'): -2,
    ('P', 'H'): -2, ('F', 'Q'): -3, ('Z', 'G'): -2, ('X', 'L'): -1,
    ('T', 'M'): -1, ('Z', 'C'): -3, ('X', 'H'): -1, ('D', 'R'): -2,
    ('B', 'W'): -4, ('X', 'D'): -1, ('Z', 'K'): 1, ('F', 'A'): -2,
    ('Z', 'W'): -3, ('F', 'E'): -3, ('D', 'N'): 1, ('B', 'K'): 0,
    ('X', 'X'): -1, ('F', 'I'): 0, ('B', 'G'): -1, ('X', 'T'): 0,
    ('F', 'M'): 0, ('B', 'C'): -3, ('Z', 'I'): -3, ('Z', 'V'): -2,
    ('S', 'S'): 4, ('L', 'Q'): -2, ('W', 'E'): -3, ('Q', 'R'): 1,
    ('N', 'N'): 6, ('W', 'M'): -1, ('Q', 'C'): -3, ('W', 'I'): -3,
    ('S', 'C'): -1, ('L', 'A'): -1, ('S', 'G'): 0, ('L', 'E'): -3,
    ('W', 'Q'): -2, ('H', 'G'): -2, ('S', 'K'): 0, ('Q', 'N'): 0,
    ('N', 'R'): 0, ('H', 'C'): -3, ('Y', 'N'): -2, ('G', 'Q'): -2,
    ('Y', 'F'): 3, ('C', 'A'): 0, ('V', 'L'): 1, ('G', 'E'): -2,
    ('G', 'A'): 0, ('K', 'R'): 2, ('E', 'D'): 2, ('Y', 'R'): -2,
    ('M', 'Q'): 0, ('T', 'I'): -1, ('C', 'D'): -3, ('V', 'F'): -1,
    ('T', 'A'): 0, ('T', 'P'): -1, ('B', 'P'): -2, ('T', 'E'): -1,
    ('V', 'N'): -3, ('P', 'G'): -2, ('M', 'A'): -1, ('K', 'H'): -1,
    ('V', 'R'): -3, ('P', 'C'): -3, ('M', 'E'): -2, ('K', 'L'): -2,
    ('V', 'V'): 4, ('M', 'I'): 1, ('T', 'Q'): -1, ('I', 'G'): -4,
    ('P', 'K'): -1, ('M', 'M'): 5, ('K', 'D'): -1, ('I', 'C'): -1,
    ('Z', 'D'): 1, ('F', 'R'): -3, ('X', 'K'): -1, ('Q', 'D'): 0,
    ('X', 'G'): -1, ('Z', 'L'): -3, ('X', 'C'): -2, ('Z', 'H'): 0,
    ('B', 'L'): -4, ('B', 'H'): 0, ('F', 'F'): 6, ('X', 'W'): -2,
    ('B', 'D'): 4, ('D', 'A'): -2, ('S', 'L'): -2, ('X', 'S'): 0,
    ('F', 'N'): -3, ('S', 'R'): -1, ('W', 'D'): -4, ('V', 'Y'): -1,
    ('W', 'L'): -2, ('H', 'R'): 0, ('W', 'H'): -2, ('H', 'N'): 1,
    ('W', 'T'): -2, ('T', 'T'): 5, ('S', 'F'): -2, ('W', 'P'): -4,
    ('L', 'D'): -4, ('B', 'I'): -3, ('L', 'H'): -3, ('S', 'N'): 1,
    ('B', 'T'): -1, ('L', 'L'): 4, ('Y', 'K'): -2, ('E', 'Q'): 2,
    ('Y', 'G'): -3, ('Z', 'S'): 0, ('Y', 'C'): -2, ('G', 'D'): -1,
    ('B', 'V'): -3, ('E', 'A'): -1, ('Y', 'W'): 2, ('E', 'E'): 5,
    ('Y', 'S'): -2, ('C', 'N'): -3, ('V', 'C'): -1, ('T', 'H'): -2,
    ('P', 'R'): -2, ('V', 'G'): -3, ('T', 'L'): -1, ('V', 'K'): -2,
    ('K', 'Q'): 1, ('R', 'A'): -1, ('I', 'R'): -3, ('T', 'D'): -1,
    ('P', 'F'): -4, ('I', 'N'): -3, ('K', 'I'): -3, ('M', 'D'): -3,
    ('V', 'W'): -3, ('W', 'W'): 11, ('M', 'H'): -2, ('P', 'N'): -2,
    ('K', 'A'): -1, ('M', 'L'): 2, ('K', 'E'): 1, ('Z', 'E'): 4,
    ('X', 'N'): -1, ('Z', 'A'): -1, ('Z', 'M'): -1, ('X', 'F'): -1,
    ('K', 'C'): -3, ('B', 'Q'): 0, ('X', 'B'): -1, ('B', 'M'): -3,
    ('F', 'C'): -2, ('Z', 'Q'): 3, ('X', 'Z'): -1, ('F', 'G'): -3,
    ('B', 'E'): 1, ('X', 'V'): -1, ('F', 'K'): -3, ('B', 'A'): -2,
    ('X', 'R'): -1, ('D', 'D'): 6, ('W', 'G'): -2, ('Z', 'F'): -3,
    ('S', 'Q'): 0, ('W', 'C'): -2, ('W', 'K'): -3, ('H', 'Q'): 0,
    ('L', 'C'): -1, ('W', 'N'): -4, ('S', 'A'): 1, ('L', 'G'): -4,
    ('W', 'S'): -3, ('S', 'E'): 0, ('H', 'E'): 0, ('S', 'I'): -2,
    ('H', 'A'): -2, ('S', 'M'): -1, ('Y', 'L'): -1, ('Y', 'H'): 2,
    ('Y', 'D'): -3, ('E', 'R'): 0, ('X', 'P'): -2, ('G', 'G'): 6,
    ('G', 'C'): -3, ('E', 'N'): 0, ('Y', 'T'): -2, ('Y', 'P'): -3,
    ('T', 'K'): -1, ('A', 'A'): 4, ('P', 'Q'): -1, ('T', 'C'): -1,
    ('V', 'H'): -3, ('T', 'G'): -2, ('I', 'Q'): -3, ('Z', 'T'): -1,
    ('C', 'R'): -3, ('V', 'P'): -2, ('P', 'E'): -1, ('M', 'C'): -1,
    ('K', 'N'): 0, ('I', 'I'): 4, ('P', 'A'): -1, ('M', 'G'): -3,
    ('T', 'S'): 1, ('I', 'E'): -3, ('P', 'M'): -2, ('M', 'K'): -1,
    ('I', 'A'): -1, ('P', 'I'): -3, ('R', 'R'): 5, ('X', 'M'): -1,
    ('L', 'I'): 2, ('X', 'I'): -1, ('Z', 'B'): 1, ('X', 'E'): -1,
    ('Z', 'N'): 0, ('X', 'A'): 0, ('B', 'R'): -1, ('B', 'N'): 3,
    ('F', 'D'): -3, ('X', 'Y'): -1, ('Z', 'R'): 0, ('F', 'H'): -1,
    ('B', 'F'): -3, ('F', 'L'): 0, ('X', 'Q'): -1, ('B', 'B'): 4
}

blosum45 = {
    ("W", "F"): 1, ("L", "R"): -2, ("S", "P"): -1, ("V", "T"): 0,
    ("Q", "Q"): 6, ("N", "A"): -1, ("Z", "Y"): -2, ("W", "R"): -2,
    ("Q", "A"): -1, ("S", "D"): 0, ("H", "H"): 10, ("S", "H"): -1,
    ("H", "D"): 0, ("L", "N"): -3, ("W", "A"): -2, ("Y", "M"): 0,
    ("G", "R"): -2, ("Y", "I"): 0, ("Y", "E"): -2, ("B", "Y"): -2,
    ("Y", "A"): -2, ("V", "D"): -3, ("B", "S"): 0, ("Y", "Y"): 8,
    ("G", "N"): 0, ("E", "C"): -3, ("Y", "Q"): -1, ("Z", "Z"): 4,
    ("V", "A"): 0, ("C", "C"): 12, ("M", "R"): -1, ("V", "E"): -3,
    ("T", "N"): 0, ("P", "P"): 9, ("V", "I"): 3, ("V", "S"): -1,
    ("Z", "P"): -1, ("V", "M"): 1, ("T", "F"): -1, ("V", "Q"): -3,
    ("K", "K"): 5, ("P", "D"): -1, ("I", "H"): -3, ("I", "D"): -4,
    ("T", "R"): -1, ("P", "L"): -3, ("K", "G"): -2, ("M", "N"): -2,
    ("P", "H"): -2, ("F", "Q"): -4, ("Z", "G"): -2, ("X", "L"): -1,
    ("T", "M"): -1, ("Z", "C"): -3, ("X", "H"): -1, ("D", "R"): -1,
    ("B", "W"): -4, ("X", "D"): -1, ("Z", "K"): 1, ("F", "A"): -2,
    ("Z", "W"): -2, ("F", "E"): -3, ("D", "N"): 2, ("B", "K"): 0,
    ("X", "X"): -1, ("F", "I"): 0, ("B", "G"): -1, ("X", "T"): 0,
    ("F", "M"): 0, ("B", "C"): -2, ("Z", "I"): -3, ("Z", "V"): -3,
    ("S", "S"): 4, ("L", "Q"): -2, ("W", "E"): -3, ("Q", "R"): 1,
    ("N", "N"): 6, ("W", "M"): -2, ("Q", "C"): -3, ("W", "I"): -2,
    ("S", "C"): -1, ("L", "A"): -1, ("S", "G"): 0, ("L", "E"): -2,
    ("W", "Q"): -2, ("H", "G"): -2, ("S", "K"): -1, ("Q", "N"): 0,
    ("N", "R"): 0, ("H", "C"): -3, ("Y", "N"): -2, ("G", "Q"): -2,
    ("Y", "F"): 3, ("C", "A"): -1, ("V", "L"): 1, ("G", "E"): -2,
    ("G", "A"): 0, ("K", "R"): 3, ("E", "D"): 2, ("Y", "R"): -1,
    ("M", "Q"): 0, ("T", "I"): -1, ("C", "D"): -3, ("V", "F"): 0,
    ("T", "A"): 0, ("T", "P"): -1, ("B", "P"): -2, ("T", "E"): -1,
    ("V", "N"): -3, ("P", "G"): -2, ("M", "A"): -1, ("K", "H"): -1,
    ("V", "R"): -2, ("P", "C"): -4, ("M", "E"): -2, ("K", "L"): -3,
    ("V", "V"): 5, ("M", "I"): 2, ("T", "Q"): -1, ("I", "G"): -4,
    ("P", "K"): -1, ("M", "M"): 6, ("K", "D"): 0, ("I", "C"): -3,
    ("Z", "D"): 1, ("F", "R"): -2, ("X", "K"): -1, ("Q", "D"): 0,
    ("X", "G"): -1, ("Z", "L"): -2, ("X", "C"): -2, ("Z", "H"): 0,
    ("B", "L"): -3, ("B", "H"): 0, ("F", "F"): 8, ("X", "W"): -2,
    ("B", "D"): 5, ("D", "A"): -2, ("S", "L"): -3, ("X", "S"): 0,
    ("F", "N"): -2, ("S", "R"): -1, ("W", "D"): -4, ("V", "Y"): -1,
    ("W", "L"): -2, ("H", "R"): 0, ("W", "H"): -3, ("H", "N"): 1,
    ("W", "T"): -3, ("T", "T"): 5, ("S", "F"): -2, ("W", "P"): -3,
    ("L", "D"): -3, ("B", "I"): -3, ("L", "H"): -2, ("S", "N"): 1,
    ("B", "T"): 0, ("L", "L"): 5, ("Y", "K"): -1, ("E", "Q"): 2,
    ("Y", "G"): -3, ("Z", "S"): 0, ("Y", "C"): -3, ("G", "D"): -1,
    ("B", "V"): -3, ("E", "A"): -1, ("Y", "W"): 3, ("E", "E"): 6,
    ("Y", "S"): -2, ("C", "N"): -2, ("V", "C"): -1, ("T", "H"): -2,
    ("P", "R"): -2, ("V", "G"): -3, ("T", "L"): -1, ("V", "K"): -2,
    ("K", "Q"): 1, ("R", "A"): -2, ("I", "R"): -3, ("T", "D"): -1,
    ("P", "F"): -3, ("I", "N"): -2, ("K", "I"): -3, ("M", "D"): -3,
    ("V", "W"): -3, ("W", "W"): 15, ("M", "H"): 0, ("P", "N"): -2,
    ("K", "A"): -1, ("M", "L"): 2, ("K", "E"): 1, ("Z", "E"): 4,
    ("X", "N"): -1, ("Z", "A"): -1, ("Z", "M"): -1, ("X", "F"): -1,
    ("K", "C"): -3, ("B", "Q"): 0, ("X", "B"): -1, ("B", "M"): -2,
    ("F", "C"): -2, ("Z", "Q"): 4, ("X", "Z"): -1, ("F", "G"): -3,
    ("B", "E"): 1, ("X", "V"): -1, ("F", "K"): -3, ("B", "A"): -1,
    ("X", "R"): -1, ("D", "D"): 7, ("W", "G"): -2, ("Z", "F"): -3,
    ("S", "Q"): 0, ("W", "C"): -5, ("W", "K"): -2, ("H", "Q"): 1,
    ("L", "C"): -2, ("W", "N"): -4, ("S", "A"): 1, ("L", "G"): -3,
    ("W", "S"): -4, ("S", "E"): 0, ("H", "E"): 0, ("S", "I"): -2,
    ("H", "A"): -2, ("S", "M"): -2, ("Y", "L"): 0, ("Y", "H"): 2,
    ("Y", "D"): -2, ("E", "R"): 0, ("X", "P"): -1, ("G", "G"): 7,
    ("G", "C"): -3, ("E", "N"): 0, ("Y", "T"): -1, ("Y", "P"): -3,
    ("T", "K"): -1, ("A", "A"): 5, ("P", "Q"): -1, ("T", "C"): -1,
    ("V", "H"): -3, ("T", "G"): -2, ("I", "Q"): -2, ("Z", "T"): -1,
    ("C", "R"): -3, ("V", "P"): -3, ("P", "E"): 0, ("M", "C"): -2,
    ("K", "N"): 0, ("I", "I"): 5, ("P", "A"): -1, ("M", "G"): -2,
    ("T", "S"): 2, ("I", "E"): -3, ("P", "M"): -2, ("M", "K"): -1,
    ("I", "A"): -1, ("P", "I"): -2, ("R", "R"): 7, ("X", "M"): -1,
    ("L", "I"): 2, ("X", "I"): -1, ("Z", "B"): 2, ("X", "E"): -1,
    ("Z", "N"): 0, ("X", "A"): 0, ("B", "R"): -1, ("B", "N"): 4,
    ("F", "D"): -4, ("X", "Y"): -1, ("Z", "R"): 0, ("F", "H"): -2,
    ("B", "F"): -3, ("F", "L"): 1, ("X", "Q"): -1, ("B", "B"): 4
}

blosum90 = {
    ("W", "F"): 0, ("L", "R"): -3, ("S", "P"): -2, ("V", "T"): -1,
    ("Q", "Q"): 7, ("N", "A"): -2, ("Z", "Y"): -3, ("W", "R"): -4,
    ("Q", "A"): -1, ("S", "D"): -1, ("H", "H"): 8, ("S", "H"): -2,
    ("H", "D"): -2, ("L", "N"): -4, ("W", "A"): -4, ("Y", "M"): -2,
    ("G", "R"): -3, ("Y", "I"): -2, ("Y", "E"): -4, ("B", "Y"): -4,
    ("Y", "A"): -3, ("V", "D"): -5, ("B", "S"): 0, ("Y", "Y"): 8,
    ("G", "N"): -1, ("E", "C"): -6, ("Y", "Q"): -3, ("Z", "Z"): 4,
    ("V", "A"): -1, ("C", "C"): 9, ("M", "R"): -2, ("V", "E"): -3,
    ("T", "N"): 0, ("P", "P"): 8, ("V", "I"): 3, ("V", "S"): -2,
    ("Z", "P"): -2, ("V", "M"): 0, ("T", "F"): -3, ("V", "Q"): -3,
    ("K", "K"): 6, ("P", "D"): -3, ("I", "H"): -4, ("I", "D"): -5,
    ("T", "R"): -2, ("P", "L"): -4, ("K", "G"): -2, ("M", "N"): -3,
    ("P", "H"): -3, ("F", "Q"): -4, ("Z", "G"): -3, ("X", "L"): -2,
    ("T", "M"): -1, ("Z", "C"): -5, ("X", "H"): -2, ("D", "R"): -3,
    ("B", "W"): -6, ("X", "D"): -2, ("Z", "K"): 1, ("F", "A"): -3,
    ("Z", "W"): -4, ("F", "E"): -5, ("D", "N"): 1, ("B", "K"): -1,
    ("X", "X"): -2, ("F", "I"): -1, ("B", "G"): -2, ("X", "T"): -1,
    ("F", "M"): -1, ("B", "C"): -4, ("Z", "I"): -4, ("Z", "V"): -3,
    ("S", "S"): 5, ("L", "Q"): -3, ("W", "E"): -5, ("Q", "R"): 1,
    ("N", "N"): 7, ("W", "M"): -2, ("Q", "C"): -4, ("W", "I"): -4,
    ("S", "C"): -2, ("L", "A"): -2, ("S", "G"): -1, ("L", "E"): -4,
    ("W", "Q"): -3, ("H", "G"): -3, ("S", "K"): -1, ("Q", "N"): 0,
    ("N", "R"): -1, ("H", "C"): -5, ("Y", "N"): -3, ("G", "Q"): -3,
    ("Y", "F"): 3, ("C", "A"): -1, ("V", "L"): 0, ("G", "E"): -3,
    ("G", "A"): 0, ("K", "R"): 2, ("E", "D"): 1, ("Y", "R"): -3,
    ("M", "Q"): 0, ("T", "I"): -1, ("C", "D"): -5, ("V", "F"): -2,
    ("T", "A"): 0, ("T", "P"): -2, ("B", "P"): -3, ("T", "E"): -1,
    ("V", "N"): -4, ("P", "G"): -3, ("M", "A"): -2, ("K", "H"): -1,
    ("V", "R"): -3, ("P", "C"): -4, ("M", "E"): -3, ("K", "L"): -3,
    ("V", "V"): 5, ("M", "I"): 1, ("T", "Q"): -1, ("I", "G"): -5,
    ("P", "K"): -2, ("M", "M"): 7, ("K", "D"): -1, ("I", "C"): -2,
    ("Z", "D"): 0, ("F", "R"): -4, ("X", "K"): -1, ("Q", "D"): -1,
    ("X", "G"): -2, ("Z", "L"): -4, ("X", "C"): -3, ("Z", "H"): 0,
    ("B", "L"): -5, ("B", "H"): -1, ("F", "F"): 7, ("X", "W"): -3,
    ("B", "D"): 4, ("D", "A"): -3, ("S", "L"): -3, ("X", "S"): -1,
    ("F", "N"): -4, ("S", "R"): -1, ("W", "D"): -6, ("V", "Y"): -3,
    ("W", "L"): -3, ("H", "R"): 0, ("W", "H"): -3, ("H", "N"): 0,
    ("W", "T"): -4, ("T", "T"): 6, ("S", "F"): -3, ("W", "P"): -5,
    ("L", "D"): -5, ("B", "I"): -5, ("L", "H"): -4, ("S", "N"): 0,
    ("B", "T"): -1, ("L", "L"): 5, ("Y", "K"): -3, ("E", "Q"): 2,
    ("Y", "G"): -5, ("Z", "S"): -1, ("Y", "C"): -4, ("G", "D"): -2,
    ("B", "V"): -4, ("E", "A"): -1, ("Y", "W"): 2, ("E", "E"): 6,
    ("Y", "S"): -3, ("C", "N"): -4, ("V", "C"): -2, ("T", "H"): -2,
    ("P", "R"): -3, ("V", "G"): -5, ("T", "L"): -2, ("V", "K"): -3,
    ("K", "Q"): 1, ("R", "A"): -2, ("I", "R"): -4, ("T", "D"): -2,
    ("P", "F"): -4, ("I", "N"): -4, ("K", "I"): -4, ("M", "D"): -4,
    ("V", "W"): -3, ("W", "W"): 11, ("M", "H"): -3, ("P", "N"): -3,
    ("K", "A"): -1, ("M", "L"): 2, ("K", "E"): 0, ("Z", "E"): 4,
    ("X", "N"): -2, ("Z", "A"): -1, ("Z", "M"): -2, ("X", "F"): -2,
    ("K", "C"): -4, ("B", "Q"): -1, ("X", "B"): -2, ("B", "M"): -4,
    ("F", "C"): -3, ("Z", "Q"): 4, ("X", "Z"): -1, ("F", "G"): -5,
    ("B", "E"): 0, ("X", "V"): -2, ("F", "K"): -4, ("B", "A"): -2,
    ("X", "R"): -2, ("D", "D"): 7, ("W", "G"): -4, ("Z", "F"): -4,
    ("S", "Q"): -1, ("W", "C"): -4, ("W", "K"): -5, ("H", "Q"): 1,
    ("L", "C"): -2, ("W", "N"): -5, ("S", "A"): 1, ("L", "G"): -5,
    ("W", "S"): -4, ("S", "E"): -1, ("H", "E"): -1, ("S", "I"): -3,
    ("H", "A"): -2, ("S", "M"): -2, ("Y", "L"): -2, ("Y", "H"): 1,
    ("Y", "D"): -4, ("E", "R"): -1, ("X", "P"): -2, ("G", "G"): 6,
    ("G", "C"): -4, ("E", "N"): -1, ("Y", "T"): -2, ("Y", "P"): -4,
    ("T", "K"): -1, ("A", "A"): 5, ("P", "Q"): -2, ("T", "C"): -2,
    ("V", "H"): -4, ("T", "G"): -3, ("I", "Q"): -4, ("Z", "T"): -1,
    ("C", "R"): -5, ("V", "P"): -3, ("P", "E"): -2, ("M", "C"): -2,
    ("K", "N"): 0, ("I", "I"): 5, ("P", "A"): -1, ("M", "G"): -4,
    ("T", "S"): 1, ("I", "E"): -4, ("P", "M"): -3, ("M", "K"): -2,
    ("I", "A"): -2, ("P", "I"): -4, ("R", "R"): 6, ("X", "M"): -1,
    ("L", "I"): 1, ("X", "I"): -2, ("Z", "B"): 0, ("X", "E"): -2,
    ("Z", "N"): -1, ("X", "A"): -1, ("B", "R"): -2, ("B", "N"): 4,
    ("F", "D"): -5, ("X", "Y"): -2, ("Z", "R"): 0, ("F", "H"): -2,
    ("B", "F"): -4, ("F", "L"): 0, ("X", "Q"): -1, ("B", "B"): 4
}

# %%
gap = -1

q = list("SIMILARITY")
p = list("PILLAR")

gap = -10

q = ['S','E','N','D']
p = ['A','N','D']

gap = -5

q = ['A','A','E','L','L']
p = ['D','A','E','E']

# 0 değerlerine sahip, üzerinde işlem yapacağımız bir matris oluştur.
stun_sayisi, satir_sayisi = len(q) + 1 , len(p) + 1;
Matrix_Global = [[0 for x in range(stun_sayisi)] for y in range(satir_sayisi)] 
Matrix_Local = [[0 for x in range(stun_sayisi)] for y in range(satir_sayisi)]

# Buradaki fonksiyonlar üzerinde işlem yapılacak olan matris elemanının, kosegen değerini, sol değerini ve üst değerini verir
#alanlar(satır,stün): 
#köşegeni(satır-1,stün-1),
def kosegen(stirIndex,stunIndex,Matrix):
    return Matrix[stirIndex-1][stunIndex-1]

#sol(satır,stun-1)
def sol(stirIndex,stunIndex,Matrix):
    return Matrix_Global[stirIndex][stunIndex-1] 
#üst(satır-1,stun)
def ust(stirIndex,stunIndex,Matrix):
    return Matrix_Global[stirIndex-1][stunIndex]


def matrixPuanlaGlobal():
    
    gapScore = gap
    for i in range(1, stun_sayisi): #ilk stun değer ataması
        Matrix_Global[0][i] = gapScore
        gapScore += gap

    gapScore = gap
    for i in range(1, satir_sayisi): #ilk satın değer ataması

        Matrix_Global[i][0] = gapScore
        gapScore += gap

    for i in range(1, satir_sayisi): #satır sayısı
        for j in range(1, stun_sayisi): #stun sayısı

            try:
                kosegenDegeri = blosum62[(p[i-1],q[j-1])] + kosegen(i,j,Matrix_Global)
            except KeyError:
                kosegenDegeri = blosum62[(q[j-1],p[i-1])] + kosegen(i,j,Matrix_Global)

            solDegeri = sol(i,j,Matrix_Global) + gap
            ustDegeri = ust(i,j,Matrix_Global) + gap

            maxDeger = max(kosegenDegeri, solDegeri, ustDegeri)

            Matrix_Global[i][j] = maxDeger
            

matrixPuanlaGlobal()
Q_global = []
sembol_global = []
P_global = []

satir_indexeleri_global = [] # renklendirme yapmak
stun_indexeleri_global = []
def hizalaGlobal(satir_indexi,stun_indexi):
    
    satir_indexeleri_global.append(satir_indexi)
    stun_indexeleri_global.append(stun_indexi)
    
    if(satir_indexi != 0 and stun_indexi != 0):
        
        if(p[satir_indexi-1] == q[stun_indexi-1]):
            
            Q_global.insert(0, q[stun_indexi-1])
            P_global.insert(0, p[satir_indexi-1])
            sembol_global.insert(0,sembol_eslesme)
            hizalaGlobal(satir_indexi-1 , stun_indexi-1)
            
        else:
            
            kosegenDegeri = Matrix_Global[satir_indexi-1][stun_indexi-1]
            solDegeri = Matrix_Global[satir_indexi][stun_indexi-1]
            ustDegeri = Matrix_Global[satir_indexi-1][stun_indexi]
            maxDeger = max(kosegenDegeri, solDegeri, ustDegeri)
            
            if(maxDeger == kosegenDegeri):
                
                Q_global.insert(0, q[stun_indexi-1])
                P_global.insert(0, p[satir_indexi-1])
                sembol_global.insert(0,sembol_eslesmeme)
                hizalaGlobal(satir_indexi-1 , stun_indexi-1)
                
            elif(maxDeger == solDegeri):
                
                Q_global.insert(0, q[stun_indexi-1])
                P_global.insert(0, bosluk)
                sembol_global.insert(0,sembol_bosluk)
                hizalaGlobal(satir_indexi,stun_indexi-1)
                
            elif(maxDeger == ustDegeri):
                
                Q_global.insert(0, bosluk)
                P_global.insert(0, p[satir_indexi-1])
                sembol_global.insert(0,sembol_bosluk)
                hizalaGlobal(satir_indexi-1,stun_indexi)


hizalaGlobal(satir_sayisi-1, stun_sayisi-1)

print("-----GLOBAL-----")
print("Q: " +' '.join(Q_global))
print("   " +' '.join(sembol_global))
print("P: " +' '.join(P_global))


import numpy
x = numpy.array(Matrix_Global)

import pandas
import pandas as pd
q.insert(0,' ')
p.insert(0,' ')
df = pandas.DataFrame(x, columns=q, index=p)

def styling_specific_cell(x,satir_indexeler,stun_indexeler):
    color = 'background-color: yellow;'
    df_styler = pd.DataFrame('', index=x.index, columns=x.columns)
    
    for i in range(len(satir_indexeler)):
        df_styler.iloc[satir_indexeler[i], stun_indexeler[i]] = color
    
    return df_styler


p01 = [" "]
for i in range(1,len(p)):
    p01.append(str(i) + " " + p[i])

q01 = [" "]
for i in range(1,len(q)):
    q01.append(str(i) + " " + q[i])
    
df01 = pandas.DataFrame(x, columns=q01, index=p01)
# Out:
# -----GLOBAL-----
# Q: A A E L L
#    ! * * !
# P: D A E E _

# %%
df
# Out:
#         A   A   E   L   L
#     0  -5 -10 -15 -20 -25
# D  -5  -2  -7  -8 -13 -18
# A -10  -1   2  -3  -8 -13
# E -15  -6  -2   7   2  -3
# E -20 -11  -7   3   4  -1

# %%
df01.style.apply(styling_specific_cell, satir_indexeler = satir_indexeleri_global, stun_indexeler = stun_indexeleri_global, axis = None)
# Out:
# <style  type="text/css" >
#     #T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row0_col0 {
#             background-color:  yellow;
#         }    #T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row1_col1 {
#             background-color:  yellow;
#         }    #T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row2_col2 {
#             background-color:  yellow;
#         }    #T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row3_col3 {
#             background-color:  yellow;
#         }    #T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row4_col4 {
#             background-color:  yellow;
#         }    #T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" > </th>        <th class="col_heading level0 col1" >1 A</th>        <th class="col_heading level0 col2" >2 A</th>        <th class="col_heading level0 col3" >3 E</th>        <th class="col_heading level0 col4" >4 L</th>        <th class="col_heading level0 col5" >5 L</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9level0_row0" class="row_heading level0 row0" > </th>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row0_col1" class="data row0 col1" >-5</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row0_col2" class="data row0 col2" >-10</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row0_col3" class="data row0 col3" >-15</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row0_col4" class="data row0 col4" >-20</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row0_col5" class="data row0 col5" >-25</td>
#             </tr>
#             <tr>
#                         <th id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9level0_row1" class="row_heading level0 row1" >1 D</th>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row1_col0" class="data row1 col0" >-5</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row1_col1" class="data row1 col1" >-2</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row1_col2" class="data row1 col2" >-7</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row1_col3" class="data row1 col3" >-8</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row1_col4" class="data row1 col4" >-13</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row1_col5" class="data row1 col5" >-18</td>
#             </tr>
#             <tr>
#                         <th id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9level0_row2" class="row_heading level0 row2" >2 A</th>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row2_col0" class="data row2 col0" >-10</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row2_col1" class="data row2 col1" >-1</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row2_col2" class="data row2 col2" >2</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row2_col3" class="data row2 col3" >-3</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row2_col4" class="data row2 col4" >-8</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row2_col5" class="data row2 col5" >-13</td>
#             </tr>
#             <tr>
#                         <th id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9level0_row3" class="row_heading level0 row3" >3 E</th>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row3_col0" class="data row3 col0" >-15</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row3_col1" class="data row3 col1" >-6</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row3_col2" class="data row3 col2" >-2</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row3_col3" class="data row3 col3" >7</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row3_col4" class="data row3 col4" >2</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row3_col5" class="data row3 col5" >-3</td>
#             </tr>
#             <tr>
#                         <th id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9level0_row4" class="row_heading level0 row4" >4 E</th>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row4_col0" class="data row4 col0" >-20</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row4_col1" class="data row4 col1" >-11</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row4_col2" class="data row4 col2" >-7</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row4_col3" class="data row4 col3" >3</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row4_col4" class="data row4 col4" >4</td>
#                         <td id="T_fd2545b0_55ca_11eb_8cdd_9c5c8e12e1d9row4_col5" class="data row4 col5" >-1</td>
#             </tr>
#     </tbody></table>
